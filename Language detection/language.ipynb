# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/dataset.csv")
data.head(5)
# Out:
#                                                 Text  language
# 0  klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1  sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2  ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3  விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4  de spons behoort tot het geslacht haliclona en...     Dutch

# %%
cv = CountVectorizer()
x = np.array(data['Text'])
y = np.array(data['language'])
x_new = cv.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_new,y,random_state=42,test_size=0.33)

# %%
model = MultinomialNB()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.953168044077135

# %%
while True:
  user = input("Enter a Text or type (q or exit) to leave: ")
  if user.lower() == 'q' or user.lower() == "exit":
    break
  data = cv.transform([user]).toarray()
  output = model.predict(data)
  print(output)
# Out:
# Enter a Text or type (q or exit) to leave: nothing
# ['Spanish']
# Enter a Text or type (q or exit) to leave: meri naam kya hai
# ['Dutch']
# Enter a Text or type (q or exit) to leave: q

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_pred = model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
